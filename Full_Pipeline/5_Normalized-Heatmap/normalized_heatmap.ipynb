# %% [markdown]
# # Z-Score Normalized PSTH Heatmap Analysis
#
# This notebook creates Z-score normalized heatmaps that combine PSTH data from multiple units.
# - **Y-axis**: Units (sorted in ascending order)
# - **X-axis**: Time relative to interval start (ms)
# - **Color**: Z-score normalized firing rate (standard deviations from unit mean)
#
# ## Z-Score Normalization Formula
# **z = (x - u) / o**
# - **z** = z-score
# - **x** = one bin's value (frequency)
# - **u** = mean of all bins for the same unit
# - **o** = standard deviation from mean of all bins from the same unit
#
# This normalization allows for better comparison across units with different baseline firing rates.
#
# ## Parameters
# Configure the analysis parameters in the cell below and run the analysis.

# %%
# Import required modules
import sys
import os
sys.path.append('.')

# Force reload of the module to pick up new changes
import importlib
if 'normalized' in sys.modules:
    importlib.reload(sys.modules['normalized'])

import normalized
from normalized import (
    create_multiple_duration_normalized_heatmaps,
    analyze_units_by_max_zscore
)
import matplotlib.pyplot as plt

# %%
# Configuration Parameters

# Data files (adjust paths as needed)
spikes_file = '../../Data/052725_1/spikes.csv'
intervals_file = '../../Data/052725_1/pico_time_adjust.csv'
spikes_path = os.path.abspath(spikes_file)
intervals_path = os.path.abspath(intervals_file)

# Analysis parameters
durations_ms = [5, 10, 25]        # Interval durations to analyze (ms)
units = None                      # Units to include (None = all units)
bin_size_ms = 0.1               # Bin size in milliseconds
pre_interval_ms = 5               # Time before interval start (ms)
post_interval_ms = 10             # Time after interval END (ms)
smooth_window = 10                 # Smoothing window (bins)

# Output settings
save_plots = True
output_dir = '../../Output/052725_1/normalized_heatmaps'

# %%
# Create Z-Score Normalized PSTH heatmaps for all specified durations

save_dir = output_dir if save_plots else None

results = create_multiple_duration_normalized_heatmaps(
    spikes_file=spikes_path,
    intervals_file=intervals_path,
    durations_ms=durations_ms,
    units=units,
    bin_size_ms=bin_size_ms,
    pre_interval_ms=pre_interval_ms,
    post_interval_ms=post_interval_ms,
    smooth_window=smooth_window,
    save_dir=save_dir
)

# Show the plots
plt.show()
# Out:
# --- Processing normalized heatmap for duration: 5ms ---
# Loading spike data from: /home/wanglab/spike-analysis/Data/052725_1/spikes.csv
# Loading interval data from: /home/wanglab/spike-analysis/Data/052725_1/pico_time_adjust.csv
# Loaded 614189 spikes and 12390 intervals
# Available units: [np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6), np.int64(7), np.int64(8), np.int64(9), np.int64(10), np.int64(11), np.int64(12), np.int64(13), np.int64(14), np.int64(15), np.int64(16), np.int64(17), np.int64(18), np.int64(19), np.int64(20), np.int64(21), np.int64(22), np.int64(23), np.int64(24), np.int64(25), np.int64(26), np.int64(27), np.int64(28), np.int64(29)]
# Available interval durations (first 5): ['0.00ms', '0.07ms', '0.13ms', '0.20ms', '0.27ms']
# Found 1025 intervals with duration 5ms (±1ms)
# Computing normalized PSTH for 29 units...
# Applying Z-score normalization...
# Warning: Unit 0 has zero standard deviation. Setting z-scores to 0.
# Warning: Unit 25 has zero standard deviation. Setting z-scores to 0.
# Warning: Unit 26 has zero standard deviation. Setting z-scores to 0.
# Saved normalized heatmap to: ../../Output/052725_1/normalized_heatmaps/normalized_psth_heatmap_5ms.png
#
# --- Processing normalized heatmap for duration: 10ms ---
# Loading spike data from: /home/wanglab/spike-analysis/Data/052725_1/spikes.csv
# Loading interval data from: /home/wanglab/spike-analysis/Data/052725_1/pico_time_adjust.csv
# Loaded 614189 spikes and 12390 intervals
# Available units: [np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6), np.int64(7), np.int64(8), np.int64(9), np.int64(10), np.int64(11), np.int64(12), np.int64(13), np.int64(14), np.int64(15), np.int64(16), np.int64(17), np.int64(18), np.int64(19), np.int64(20), np.int64(21), np.int64(22), np.int64(23), np.int64(24), np.int64(25), np.int64(26), np.int64(27), np.int64(28), np.int64(29)]
# Available interval durations (first 5): ['0.00ms', '0.07ms', '0.13ms', '0.20ms', '0.27ms']
# Found 8321 intervals with duration 10ms (±1ms)
# Computing normalized PSTH for 29 units...
# Applying Z-score normalization...
# Saved normalized heatmap to: ../../Output/052725_1/normalized_heatmaps/normalized_psth_heatmap_10ms.png
#
# --- Processing normalized heatmap for duration: 25ms ---
# Loading spike data from: /home/wanglab/spike-analysis/Data/052725_1/spikes.csv
# Loading interval data from: /home/wanglab/spike-analysis/Data/052725_1/pico_time_adjust.csv
# Loaded 614189 spikes and 12390 intervals
# Available units: [np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6), np.int64(7), np.int64(8), np.int64(9), np.int64(10), np.int64(11), np.int64(12), np.int64(13), np.int64(14), np.int64(15), np.int64(16), np.int64(17), np.int64(18), np.int64(19), np.int64(20), np.int64(21), np.int64(22), np.int64(23), np.int64(24), np.int64(25), np.int64(26), np.int64(27), np.int64(28), np.int64(29)]
# Available interval durations (first 5): ['0.00ms', '0.07ms', '0.13ms', '0.20ms', '0.27ms']
# Found 2107 intervals with duration 25ms (±1ms)
# Computing normalized PSTH for 29 units...
# Applying Z-score normalization...
# Warning: Unit 24 has zero standard deviation. Setting z-scores to 0.
# Saved normalized heatmap to: ../../Output/052725_1/normalized_heatmaps/normalized_psth_heatmap_25ms.png

# %%
# Analyze units by their highest maximum z-score values
unit_rankings = analyze_units_by_max_zscore(results, display_results=True)
# Out:
# === Duration: 5ms ===
# Units ordered by highest maximum z-score (positive direction):
# Rank	Unit	Max Z-Score
# ------------------------------
#  1	Unit 22	   2.500
#  2	Unit 30	   2.227
#  3	Unit 19	   2.218
#  4	Unit 14	   2.117
#  5	Unit 28	   2.099
#  6	Unit 37	   2.062
#  7	Unit 45	   2.030
#  8	Unit 17	   2.005
#  9	Unit 13	   1.951
# 10	Unit 16	   1.935
# 11	Unit 43	   1.913
# 12	Unit 20	   1.875
# 13	Unit 12	   1.854
# 14	Unit  7	   1.847
# 15	Unit 39	   1.797
# 16	Unit 10	   1.795
# 17	Unit 21	   1.788
# 18	Unit 27	   1.778
# 19	Unit 29	   1.773
# 20	Unit 38	   1.765
# 21	Unit 41	   1.738
# 22	Unit  9	   1.723
# 23	Unit  3	   1.715
# 24	Unit 24	   1.715
# 25	Unit  1	   1.714
# 26	Unit  4	   1.709
# 27	Unit 42	   1.705
# 28	Unit 23	   1.666
# 29	Unit  6	   1.651
# 30	Unit 11	   1.640
# 31	Unit 25	   1.630
# 32	Unit  5	   1.624
# 33	Unit 26	   1.599
# 34	Unit  8	   1.570
# 35	Unit  2	   1.507
# 36	Unit 15	   0.000
# 37	Unit 18	   0.000
# 38	Unit 31	   0.000
# 39	Unit 32	   0.000
# 40	Unit 33	   0.000
# 41	Unit 34	   0.000
# 42	Unit 35	   0.000
# 43	Unit 36	   0.000
# 44	Unit 40	   0.000
# 45	Unit 44	   0.000
#
# === Duration: 10ms ===
# Units ordered by highest maximum z-score (positive direction):
# Rank	Unit	Max Z-Score
# ------------------------------
#  1	Unit 13	   3.120
#  2	Unit 40	   2.901
#  3	Unit 14	   2.755
#  4	Unit  4	   2.470
#  5	Unit 18	   2.461
#  6	Unit 12	   2.401
#  7	Unit 38	   2.395
#  8	Unit 44	   2.394
#  9	Unit 17	   2.314
# 10	Unit  5	   2.313
# 11	Unit 27	   2.313
# 12	Unit  9	   2.225
# 13	Unit 22	   2.206
# 14	Unit 43	   2.146
# 15	Unit 21	   2.121
# 16	Unit  3	   2.119
# 17	Unit 16	   2.111
# 18	Unit  8	   2.106
# 19	Unit 42	   2.070
# 20	Unit 11	   2.070
# 21	Unit 41	   2.061
# 22	Unit 29	   2.059
# 23	Unit 23	   1.997
# 24	Unit  2	   1.969
# 25	Unit  1	   1.954
# 26	Unit 24	   1.923
# 27	Unit 30	   1.919
# 28	Unit 20	   1.864
# 29	Unit 10	   1.834
# 30	Unit 37	   1.751
# 31	Unit  6	   1.738
# 32	Unit 26	   1.644
# 33	Unit 45	   1.623
# 34	Unit 39	   1.499
# 35	Unit  7	   1.425
# 36	Unit 28	   1.420
# 37	Unit 35	   1.414
# 38	Unit 19	   1.269
# 39	Unit 25	   1.086
# 40	Unit 15	   0.000
# 41	Unit 31	   0.000
# 42	Unit 32	   0.000
# 43	Unit 33	   0.000
# 44	Unit 34	   0.000
# 45	Unit 36	   0.000
#
# === Duration: 25ms ===
# Units ordered by highest maximum z-score (positive direction):
# Rank	Unit	Max Z-Score
# ------------------------------
#  1	Unit  1	   3.016
#  2	Unit 41	   2.847
#  3	Unit  8	   2.831
#  4	Unit  9	   2.803
#  5	Unit 14	   2.790
#  6	Unit 21	   2.769
#  7	Unit  4	   2.511
#  8	Unit 23	   2.486
#  9	Unit 29	   2.482
# 10	Unit 22	   2.462
# 11	Unit  2	   2.412
# 12	Unit 19	   2.385
# 13	Unit 13	   2.364
# 14	Unit 12	   2.213
# 15	Unit 30	   2.192
# 16	Unit 35	   2.164
# 17	Unit 11	   2.139
# 18	Unit 38	   2.122
# 19	Unit 16	   2.116
# 20	Unit 27	   2.052
# 21	Unit 25	   2.042
# 22	Unit  7	   2.024
# 23	Unit  5	   1.981
# 24	Unit  6	   1.900
# 25	Unit 26	   1.874
# 26	Unit 17	   1.775
# 27	Unit 45	   1.764
# 28	Unit 37	   1.741
# 29	Unit 39	   1.729
# 30	Unit 28	   1.713
# 31	Unit 20	   1.681
# 32	Unit 43	   1.675
# 33	Unit  3	   1.674
# 34	Unit 24	   1.619
# 35	Unit 42	   1.545
# 36	Unit 44	   1.528
# 37	Unit 10	   1.525
# 38	Unit 15	   0.000
# 39	Unit 18	   0.000
# 40	Unit 31	   0.000
# 41	Unit 32	   0.000
# 42	Unit 33	   0.000
# 43	Unit 34	   0.000
# 44	Unit 36	   0.000
# 45	Unit 40	   0.000
